# %%
# !pip install "tensorflow>=2.18" "keras"

# %%
import keras
import tensorflow as tf

model = keras.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/1577063002.py in <cell line: 0>()
#       2 import tensorflow as tf
#       3
# ----> 4 model = keras.applications.xception()
#
# TypeError: 'module' object is not callable
