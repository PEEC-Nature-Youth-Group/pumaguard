# %%
# !pip install 'tensorflow==2.18.1' keras setuptools

# %%
import keras
import tensorflow as tf

model = keras.applications.xception()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import keras
#       2 import tensorflow as tf
#       4 model = keras.applications.xception()
#
# File ~/Work/github.com/PEEC-Nature-Youth-Group/pumaguard/venv/lib/python3.12/site-packages/keras/__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File ~/Work/github.com/PEEC-Nature-Youth-Group/pumaguard/venv/lib/python3.12/site-packages/keras/api/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# ...
